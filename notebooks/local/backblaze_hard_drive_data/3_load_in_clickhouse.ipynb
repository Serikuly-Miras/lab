# %% [markdown]
# ## Prerequisites

# %%
# %pip install clickhouse-connect --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import clickhouse_connect
import os
import polars as pl
from dotenv import load_dotenv

load_dotenv()

host = os.getenv("CLICKHOUSE_HOST")
username = os.getenv("CLICKHOUSE_USER")
password = os.getenv("CLICKHOUSE_PASSWORD")

client = clickhouse_connect.get_client(
    host=host,
    port=8123,
    username=username,
    password=password,
)

# %%
df = pl.from_pandas(
    client.query_df(
        f"""
            SELECT *
            FROM s3(
                '{os.getenv("S3_AWS_URL_NODE_PORT")}/data-raw/Backblaze-Hard-Drive-Data/*/*.csv',
                '{os.getenv("S3_AWS_ACCESS_KEY_ID")}',
                '{os.getenv("S3_AWS_SECRET_ACCESS_KEY")}',
                'CSVWithNames'
            )
            LIMIT 5
    """
    )
)
df
# Out:
# shape: (5, 197)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ date      ┆ serial_nu ┆ model     ┆ capacity_ ┆ … ┆ smart_254 ┆ smart_254 ┆ smart_255 ┆ smart_25 │
# │ ---       ┆ mber      ┆ ---       ┆ bytes     ┆   ┆ _normaliz ┆ _raw      ┆ _normaliz ┆ 5_raw    │
# │ datetime[ ┆ ---       ┆ str       ┆ ---       ┆   ┆ ed        ┆ ---       ┆ ed        ┆ ---      │
# │ ns]       ┆ str       ┆           ┆ i64       ┆   ┆ ---       ┆ i64       ┆ ---       ┆ str      │
# │           ┆           ┆           ┆           ┆   ┆ i64       ┆           ┆ str       ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 2025-01-0 ┆ 2207E60CC ┆ CT250MX50 ┆ 250059350 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 1         ┆ 65A       ┆ 0SSD1     ┆ 016       ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2025-01-0 ┆ 2340E87B9 ┆ CT250MX50 ┆ 250059350 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 1         ┆ 2B5       ┆ 0SSD1     ┆ 016       ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2025-01-0 ┆ 2EGK64VX  ┆ HGST HUH7 ┆ 800156322 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 1         ┆           ┆ 28080ALE6 ┆ 2016      ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆ 04        ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2025-01-0 ┆ 2EHZAKAX  ┆ HGST HUH7 ┆ 800156322 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 1         ┆           ┆ 28080ALE6 ┆ 2016      ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆ 04        ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2025-01-0 ┆ 2EJ02A1X  ┆ HGST HUH7 ┆ 800156322 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 1         ┆           ┆ 28080ALE6 ┆ 2016      ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆ 04        ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# ## Loading data from s3

# %%
client.command(
    f"""
    CREATE TABLE dwh.backblaze_hard_drive_data
    ENGINE = MergeTree()
    ORDER BY assumeNotNull(date)
    AS SELECT *, FROM s3(
        '{os.getenv("S3_AWS_URL_NODE_PORT")}/data-raw/Backblaze-Hard-Drive-Data/*/*.csv',
        '{os.getenv("S3_AWS_ACCESS_KEY_ID")}',
        '{os.getenv("S3_AWS_SECRET_ACCESS_KEY")}',
        'CSVWithNames'
    )
    """
)

# %%
df = pl.from_pandas(
    client.query_df(
        """
        SELECT * 
        FROM dwh.backblaze_hard_drive_data 
        LIMIT 10
        """
    )
)
df
# Out:
# shape: (10, 197)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ date      ┆ serial_nu ┆ model     ┆ capacity_ ┆ … ┆ smart_254 ┆ smart_254 ┆ smart_255 ┆ smart_25 │
# │ ---       ┆ mber      ┆ ---       ┆ bytes     ┆   ┆ _normaliz ┆ _raw      ┆ _normaliz ┆ 5_raw    │
# │ datetime[ ┆ ---       ┆ str       ┆ ---       ┆   ┆ ed        ┆ ---       ┆ ed        ┆ ---      │
# │ ns]       ┆ str       ┆           ┆ i64       ┆   ┆ ---       ┆ i64       ┆ ---       ┆ str      │
# │           ┆           ┆           ┆           ┆   ┆ i64       ┆           ┆ str       ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 2025-01-0 ┆ 2207E60CC ┆ CT250MX50 ┆ 250059350 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 1         ┆ 65A       ┆ 0SSD1     ┆ 016       ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2025-01-0 ┆ 2340E87B9 ┆ CT250MX50 ┆ 250059350 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 1         ┆ 2B5       ┆ 0SSD1     ┆ 016       ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2025-01-0 ┆ 2EGK64VX  ┆ HGST HUH7 ┆ 800156322 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 1         ┆           ┆ 28080ALE6 ┆ 2016      ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆ 04        ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2025-01-0 ┆ 2EHZAKAX  ┆ HGST HUH7 ┆ 800156322 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 1         ┆           ┆ 28080ALE6 ┆ 2016      ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆ 04        ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2025-01-0 ┆ 2EJ02A1X  ┆ HGST HUH7 ┆ 800156322 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 1         ┆           ┆ 28080ALE6 ┆ 2016      ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆ 04        ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2025-01-0 ┆ 7LZ021LA  ┆ Seagate   ┆ 250059350 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 1         ┆           ┆ BarraCuda ┆ 016       ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆ SSD       ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ ZA250CM1… ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2025-01-0 ┆ S2ZYJ9CF5 ┆ ST500LM01 ┆ 500107862 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 1         ┆ 11681     ┆ 2 HN      ┆ 016       ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2025-01-0 ┆ S2ZYJ9GGB ┆ ST500LM01 ┆ 500107862 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 1         ┆ 01000     ┆ 2 HN      ┆ 016       ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2025-01-0 ┆ S2ZYJ9GGB ┆ ST500LM01 ┆ 500107862 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 1         ┆ 01001     ┆ 2 HN      ┆ 016       ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2025-01-0 ┆ S2ZYJ9GGB ┆ ST500LM01 ┆ 500107862 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 1         ┆ 01020     ┆ 2 HN      ┆ 016       ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
df = pl.from_pandas(
    client.query_df(
        """
        SELECT count(*) as total_rows
        FROM dwh.backblaze_hard_drive_data
        """
    )
)
df
# Out:
# shape: (1, 1)
# ┌────────────┐
# │ total_rows │
# │ ---        │
# │ u64        │
# ╞════════════╡
# │ 56608028   │
# └────────────┘
